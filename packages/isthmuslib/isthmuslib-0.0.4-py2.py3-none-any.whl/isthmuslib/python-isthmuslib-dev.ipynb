# %% [markdown]
# # Isthmuslib dev

# %% [markdown]
# ### Imports

# %%
import isthmuslib as isli

# %%
isli.demodata()
# Out:
# ([1, 2, 5, 10, 20, 50, 100, 200, 500, 1000],
#  [1, 4, 8, 20, 30, 40, 120, 250, 700, 1100])

# %%
isli.version()
# Out:
# '0.0.4'

# %% [markdown]
# ### hist 1d

# %%
x, y = isli.demodata();
isli.singlehist(x);

# %% [markdown]
# ### hist 2d

# %%
isli.singlehist2d(x,y);

# %%
y2 = [-i for i in x]

# %%
testdict = {'y1':y, 'y2':y2}

# %%
isli.scatter(x,y, xscale='log', yscale='log', markersize=10);

# %%
f = isli.scatter(x,testdict, xscale='log', yscale='linear', markersize=10, legend=True);

# %%
isli.hist(x);

# %%
isli.hist(testdict);

# %%
isli.hist(testdict);
