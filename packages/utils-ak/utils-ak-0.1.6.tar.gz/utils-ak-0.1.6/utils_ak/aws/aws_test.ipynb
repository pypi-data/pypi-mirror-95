# %%
from s3manager import S3
s3 = S3()
s3.download('test', overwrite=False, local='Users/a4u1/Desktop/local_test_1', remove=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/botocore/vendored/requests/packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, **httplib_request_kw)
#     371             try:  # Python 2.7, use buffering of HTTP responses
# --> 372                 httplib_response = conn.getresponse(buffering=True)
#     373             except TypeError:  # Python 2.6 and older
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-f7886cf4eb84> in <module>()
#       1 from s3manager import S3
#       2 s3 = S3()
# ----> 3 s3.download('test', overwrite=False, local='/local_test_1', remove=True)
# ...

# %%
from s3manager import S3
s3 = S3()
s3.upload('test_transfer/', bucket='Binance', target='test_transfer', overwrite=True, remove=True)
# Out:
# test_transfer
# test_transfer/
# test_transfer/.DS_Store
# test_transfer/t2/Screen Shot 2017-11-21 at 00.11.07.jpg
# test_transfer/t3/rosenbaum.jpg
# test_transfer/t1/rosenbaum.jpg
# test_transfer/t1/FRIEDMAN.jpg

# %%
from s3manager import S3
s3 = S3()
s3.delete(target='test_transfer/test_transfer/t1/rosenbaum.jpg')
